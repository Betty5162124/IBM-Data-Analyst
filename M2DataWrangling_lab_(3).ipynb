# %% [markdown]
# <a href="https://colab.research.google.com/github/Betty5162124/tesetrpo/blob/main/M2DataWrangling_lab_(3).ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# <p style="text-align:center">
#     <a href="https://skills.network/?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01" target="_blank">
#     <img src="https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/assets/logos/SN_web_lightmode.png" width="200" alt="Skills Network Logo"  />
#     </a>
# </p>

# %% [markdown]
# # **Data Wrangling Lab**

# %% [markdown]
# Estimated time needed: **45 to 60** minutes

# %% [markdown]
# In this assignment you will be performing data wrangling.

# %% [markdown]
# ## Objectives

# %% [markdown]
# In this lab you will perform the following:

# %% [markdown]
# -   Identify duplicate values in the dataset.
#
# -   Remove duplicate values from the dataset.
#
# -   Identify missing values in the dataset.
#
# -   Impute the missing values in the dataset.
#
# -   Normalize data in the dataset.

# %% [markdown]
# <hr>

# %% [markdown]
# ## Hands on Lab

# %% [markdown]
# Import pandas module.

# %%
import pandas as pd

# %% [markdown]
# Load the dataset into a dataframe.

# %%
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")

# %% [markdown]
# ## Finding duplicates

# %% [markdown]
# In this section you will identify duplicate values in the dataset.

# %% [markdown]
#  Find how many duplicate rows exist in the dataframe.

# %%
# your code goes here
import pandas as pd

# Load the dataset
df = pd.read_csv("https://cf-courses-data.s3.us.cloud-object-storage.appdomain.cloud/IBM-DA0321EN-SkillsNetwork/LargeData/m1_survey_data.csv")

# Find the number of duplicate rows
num_duplicates = df.duplicated().sum()

num_duplicates
# Out:
# 154

# %% [markdown]
# ## Removing duplicates

# %% [markdown]
# Remove the duplicate rows from the dataframe.

# %%
# your code goes here
# Remove duplicate rows
df = df.drop_duplicates()

# Verify the removal by checking the number of rows
df.shape
# Out:
# (11398, 85)

# %% [markdown]
# Verify if duplicates were actually dropped.

# %%
# your code goes here
# Check if there are any remaining duplicate rows
num_duplicates_after = df.duplicated().sum()

num_duplicates_after
# Out:
# 0

# %% [markdown]
# ## Finding Missing values

# %% [markdown]
# Find the missing values for all columns.

# %%
# your code goes here
# Find missing values for all columns
missing_values = df.isnull().sum()

missing_values
# Out:
# Respondent        0
# MainBranch        0
# Hobbyist          0
# OpenSourcer       0
# OpenSource       81
#                ...
# Sexuality       542
# Ethnicity       675
# Dependents      140
# SurveyLength     19
# SurveyEase       14
# Length: 85, dtype: int64

# %% [markdown]
# Find out how many rows are missing in the column 'WorkLoc'

# %%
# your code goes here
# Find the number of missing values in the 'WorkLoc' column
missing_workloc = df['WorkLoc'].isnull().sum()

missing_workloc
# Out:
# 32

# %% [markdown]
# ## Imputing missing values

# %% [markdown]
# Find the  value counts for the column WorkLoc.

# %%
# your code goes here
# Find the value counts for the 'WorkLoc' column
workloc_value_counts = df['WorkLoc'].value_counts()

workloc_value_counts
# Out:
# WorkLoc
# Office                                            6806
# Home                                              3589
# Other place, such as a coworking space or cafe     971
# Name: count, dtype: int64

# %% [markdown]
# Identify the value that is most frequent (majority) in the WorkLoc column.

# %%
#make a note of the majority value here, for future reference
# Find the most frequent value in the 'WorkLoc' column
most_frequent_workloc = df['WorkLoc'].value_counts().idxmax()

most_frequent_workloc
# Out:
# 'Office'

# %% [markdown]
# Impute (replace) all the empty rows in the column WorkLoc with the value that you have identified as majority.

# %%
# your code goes here
# Impute missing values in the 'WorkLoc' column with the most frequent value
df['WorkLoc'] = df['WorkLoc'].fillna(most_frequent_workloc)

# Verify the imputation by checking for missing values again
missing_workloc_after = df['WorkLoc'].isnull().sum()

missing_workloc_after
# Out:
# 0

# %% [markdown]
# After imputation there should ideally not be any empty rows in the WorkLoc column.

# %% [markdown]
# Verify if imputing was successful.

# %%
# your code goes here
# Verify if imputing was successful by checking for any remaining missing values in 'WorkLoc'
missing_workloc_after = df['WorkLoc'].isnull().sum()

missing_workloc_after
# Out:
# 0

# %%
# Find the number of unique values in the 'CompFreq' column
num_unique_compfreq = df['CompFreq'].nunique()

num_unique_compfreq
# Out:
# 0

# %% [markdown]
# ## Normalizing data

# %% [markdown]
# There are two columns in the dataset that talk about compensation.
#
# One is "CompFreq". This column shows how often a developer is paid (Yearly, Monthly, Weekly).
#
# The other is "CompTotal". This column talks about how much the developer is paid per Year, Month, or Week depending upon his/her "CompFreq".
#
# This makes it difficult to compare the total compensation of the developers.
#
# In this section you will create a new column called 'NormalizedAnnualCompensation' which contains the 'Annual Compensation' irrespective of the 'CompFreq'.
#
# Once this column is ready, it makes comparison of salaries easy.

# %% [markdown]
# <hr>

# %% [markdown]
# List out the various categories in the column 'CompFreq'

# %%
# your code goes here
# Create a mapping for CompFreq
compfreq_mapping = {
    'Yearly': 1,
    'Monthly': 12,
    'Weekly': 52
}

# Map the CompFreq values to the corresponding numbers
df['CompFreq'] = df['CompFreq'].map(compfreq_mapping)

# Calculate the NormalizedAnnualCompensation
df['NormalizedAnnualCompensation'] = df['CompTotal'] * df['CompFreq']

# Display the first few rows to verify
df[['CompFreq', 'CompTotal', 'NormalizedAnnualCompensation']].head()
# Out:
#    CompFreq  CompTotal  NormalizedAnnualCompensation
# 0       1.0    61000.0                       61000.0
# 1       1.0   138000.0                      138000.0
# 2       1.0    90000.0                       90000.0
# 3      12.0    29000.0                      348000.0
# 4       1.0    90000.0                       90000.0
# <h4 class="colab-quickchart-section-title">Distributions</h4>
# <style>
#   .colab-quickchart-section-title {
#       clear: both;
#   }
# </style>
# from matplotlib import pyplot as plt
# _df_0['index'].plot(kind='hist', bins=20, title='index')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_1['CompFreq'].plot(kind='hist', bins=20, title='CompFreq')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# _df_2['CompTotal'].plot(kind='hist', bins=20, title='CompTotal')
# plt.gca().spines[['top', 'right',]].set_visible(False)
# from matplotlib import pyplot as plt
# ...

# %%
# Ensure duplicate rows have been removed (assuming df is already cleaned)
# Filter the dataframe for respondents being paid yearly
yearly_payers = df[df['CompFreq'] == 1]

# Count the number of respondents being paid yearly
num_yearly_payers = yearly_payers.shape[0]

num_yearly_payers
# Out:
# 0

# %% [markdown]
# Create a new column named 'NormalizedAnnualCompensation'. Use the hint given below if needed.

# %% [markdown]
# Double click to see the **Hint**.
#
# <!--
#
# Use the below logic to arrive at the values for the column NormalizedAnnualCompensation.
#
# If the CompFreq is Yearly then use the exising value in CompTotal
# If the CompFreq is Monthly then multiply the value in CompTotal with 12 (months in an year)
# If the CompFreq is Weekly then multiply the value in CompTotal with 52 (weeks in an year)
#
# -->

# %%
# your code goes here
# Create a mapping for CompFreq
compfreq_mapping = {
    'Yearly': 1,
    'Monthly': 12,
    'Weekly': 52
}

# Map the CompFreq values to the corresponding numbers
df['CompFreq'] = df['CompFreq'].map(compfreq_mapping)

# Calculate the NormalizedAnnualCompensation
df['NormalizedAnnualCompensation'] = df['CompTotal'] * df['CompFreq']

# Display the first few rows to verify
df[['CompFreq', 'CompTotal', 'NormalizedAnnualCompensation']].head()
# Out:
#    CompFreq  CompTotal  NormalizedAnnualCompensation
# 0       NaN    61000.0                           NaN
# 1       NaN   138000.0                           NaN
# 2       NaN    90000.0                           NaN
# 3       NaN    29000.0                           NaN
# 4       NaN    90000.0                           NaN

# %%
# Ensure duplicate rows have been removed (assuming df is already cleaned)
# Filter the dataframe for respondents being paid yearly
yearly_payers = df[df['CompFreq'] == 1]

# Count the number of respondents being paid yearly
num_yearly_payers = yearly_payers.shape[0]

num_yearly_payers
# Out:
# 0

# %%
# List out the various categories in the 'CompFreq' column after mapping
compfreq_categories = df['CompFreq'].unique()

compfreq_categories
# Out:
# array([nan])

# %%
# Filter the dataframe for respondents being paid yearly
yearly_payers = df[df['CompFreq'] == 1]

# Count the number of respondents being paid yearly
num_yearly_payers = yearly_payers.shape[0]

num_yearly_payers
# Out:
# 0

# %%
# Assuming duplicates have already been removed
# Filter the dataframe for respondents being paid yearly
yearly_payers = df[df['CompFreq'] == 1]

# Count the number of respondents being paid yearly
num_yearly_payers = yearly_payers.shape[0]

num_yearly_payers
# Out:
# 0

# %% [markdown]
# ## Authors

# %% [markdown]
# Ramesh Sannareddy

# %% [markdown]
# ### Other Contributors

# %% [markdown]
# Rav Ahuja

# %% [markdown]
# ## Change Log

# %% [markdown]
# | Date (YYYY-MM-DD) | Version | Changed By        | Change Description                 |
# | ----------------- | ------- | ----------------- | ---------------------------------- |
# | 2020-10-17        | 0.1     | Ramesh Sannareddy | Created initial version of the lab |

# %% [markdown]
#  Copyright © 2020 IBM Corporation. This notebook and its source code are released under the terms of the [MIT License](https://cognitiveclass.ai/mit-license?utm_medium=Exinfluencer&utm_source=Exinfluencer&utm_content=000026UJ&utm_term=10006555&utm_id=NA-SkillsNetwork-Channel-SkillsNetworkCoursesIBMDA0321ENSkillsNetwork928-2022-01-01&cm_mmc=Email_Newsletter-_-Developer_Ed%2BTech-_-WW_WW-_-SkillsNetwork-Courses-IBM-DA0321EN-SkillsNetwork-21426264&cm_mmca1=000026UJ&cm_mmca2=10006555&cm_mmca3=M12345678&cvosrc=email.Newsletter.M12345678&cvo_campaign=000026UJ).
